# %% [markdown]
# Based on paper:
#
# Özer, İlyas, Serhat Berat Efe, and Harun Özbay. "CNN/Bi‐LSTM‐based deep learning algorithm for classification of power quality disturbances by using spectrogram images." International Transactions on Electrical Energy Systems 31.12 (2021): e13204.

# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models

from keras.layers import GaussianNoise
from IPython import display

from parameters_CINC11CINC17_unbalanced import parameters

# Set the seed value for experiment reproducibility.
seed = 2
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# !python --version 

print('Tensorflow version', tf.__version__)
# Out:
# Python 3.8.11
# Tensorflow version 2.9.1

# %%
parameters = parameters()
data_length = parameters['data_length']

# %% [markdown]
# ### Import dataset

# %%
dataset_path = parameters['path_training_data']
model_save_path = parameters['path_model']
data_dir = pathlib.Path(dataset_path)

# %% [markdown]
# The dataset WAV files are stored in two folders: `0` and `1`

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['0' '1']

# %% [markdown]
# Extract the ECGs into a list called `filenames`, and shuffle it:

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total samples:', num_samples)
print('Number of samples per label:', len(tf.io.gfile.listdir(str(data_dir/commands[0]))), len(tf.io.gfile.listdir(str(data_dir/commands[1]))))
# print('Example file tensor:', filenames[0])
# Out:
# Number of total samples: 13912
# Number of samples per label: 2024

# %% [markdown]
# Split `filenames` into training, validation and test sets using a 80:10:10 ratio, respectively:
# # cross validation

# %%
nr_train = int(num_samples * 0.8)
nr_test_val = int(num_samples / 10)

train_files = filenames[:nr_train]
val_files = filenames[nr_train: nr_train + nr_test_val]
test_files = filenames[-nr_test_val:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 11129
# Validation set size 1391
# Test set size 1391

# %% [markdown]
# ## Read the ecg files and their labels

# %% [markdown]
# In this section you will preprocess the dataset, creating decoded tensors for the waveforms and the corresponding labels. Note that:
#
# - Each WAV file contains time-series data with a set number of samples per second.
# - Each sample represents the <a href="https://en.wikipedia.org/wiki/Amplitude" class="external">amplitude</a> of the ECG signal at that specific time.
# - In a <a href="https://en.wikipedia.org/wiki/Audio_bit_depth" class="external">16-bit</a> system, like WAV files, the amplitude values range from -32,768 to 32,767.
# - The <a href="https://en.wikipedia.org/wiki/Sampling_(signal_processing)#Audio_sampling" class="external">sample rate</a> for the ECG data used is 500 Hz
#
# The shape of the tensor returned by `tf.audio.decode_wav` is `[samples, channels]`, which is `[5000, 1]` for 500 Hz 10 second data.

# %%
test_file = tf.io.read_file(dataset_path+'/1/A00001.wav')
test_ecg, _ = tf.audio.decode_wav(contents=test_file)
test_ecg.shape
# Out:
# TensorShape([5000, 1])

# %% [markdown]
# Now, let's define a function that preprocesses the dataset's raw WAV ECG files into audio tensors:

# %%
def decode_wav_file(ecg_binary):
  # Decode WAV-encoded audio files to `float32` tensors, normalized
  # to the [-1.0, 1.0] range. Return `float32` audio and a sample rate.
  # Since all the data is single channel (mono), drop the `channels`
  # axis from the array.
    ecg, _ = tf.audio.decode_wav(contents=ecg_binary)
    return tf.squeeze(ecg, axis=-1)

# %% [markdown]
# Define a function that creates labels using the parent directories for each file:
#
# - Split the file paths into `tf.RaggedTensor`s (tensors with ragged dimensions—with slices that may have different lengths).

# %%
def get_label(file_path):
    parts = tf.strings.split(
      input=file_path,
      sep=os.path.sep)
    # Note: You'll use indexing here instead of tuple unpacking to enable this
    # to work in a TensorFlow graph.
    return parts[-2]

# %% [markdown]
# Define another helper function—`get_waveform_and_label`—that puts it all together:
#
# - The input is the WAV ECG file path.
# - The output is a tuple containing the ECG and label tensors ready for supervised learning.

# %%
def get_waveform_and_label(file_path):
    label = get_label(file_path)
    ecg_binary = tf.io.read_file(file_path)
    waveform = decode_wav_file(ecg_binary)
    return waveform, label

# %% [markdown]
# Build the training set to extract the ECG-label pairs:
#
# - Create a `tf.data.Dataset` with `Dataset.from_tensor_slices` and `Dataset.map`, using `get_waveform_and_label` defined earlier.
#
# You'll build the validation and test sets using a similar procedure later on.

# %%
AUTOTUNE = tf.data.AUTOTUNE

files_ds = tf.data.Dataset.from_tensor_slices(train_files)

waveform_ds = files_ds.map(
    map_func=get_waveform_and_label,
    num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Let's plot a few ECG waveforms:

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))

for i, (ecg, label) in enumerate(waveform_ds.take(n)):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    ax.plot(ecg.numpy())
    ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
    label = label.numpy().decode('utf-8')
    ax.set_title(label)

plt.show()

# %% [markdown]
# ## Convert waveforms to spectrograms
#
# The waveforms in the dataset are represented in the time domain. Next, you'll transform the waveforms from the time-domain signals into the time-frequency-domain signals by computing the <a href="https://en.wikipedia.org/wiki/Short-time_Fourier_transform" class="external">short-time Fourier transform (STFT)</a> to convert the waveforms to as <a href="https://en.wikipedia.org/wiki/Spectrogram" clas="external">spectrograms</a>, which show frequency changes over time and can be represented as 2D images. You will feed the spectrogram images into your neural network to train the model.
#
# A Fourier transform (`tf.signal.fft`) converts a signal to its component frequencies, but loses all time information. In comparison, STFT (`tf.signal.stft`) splits the signal into windows of time and runs a Fourier transform on each window, preserving some time information, and returning a 2D tensor that you can run standard convolutions on.
#
# Create a utility function for converting waveforms to spectrograms:
#
# - When calling `tf.signal.stft`, choose the `frame_length` and `frame_step` parameters such that the generated spectrogram "image" is almost square.
# - The STFT produces an array of complex numbers representing magnitude and phase. However, in this tutorial you'll only use the magnitude, which you can derive by applying `tf.abs` on the output of `tf.signal.stft`.

# %%
def get_spectrogram(waveform):
    # cropping for waveform smaller than the desired 5000 (not the case for this data)
#     waveform = waveform[:5000]

    # Cast the waveform tensors' dtype to float32.
    waveform = tf.cast(waveform, dtype=tf.float32)
    
    # In case the data is different length (not the case for this data)
#     zero_padding = tf.zeros(
#       [input_len] - tf.shape(waveform),
#       dtype=tf.float32)
#     equal_length = tf.concat([waveform, zero_padding], 0) 

    # Convert the waveform to a spectrogram via a STFT.
    spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
    # Obtain the magnitude of the STFT.
    spectrogram = tf.abs(spectrogram)
    # Add a `channels` dimension, so that the spectrogram can be used
    # as image-like input data with convolution layers (which expect
    # shape (`batch_size`, `height`, `width`, `channels`).
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram

# %% [markdown]
# Next, start exploring the data. Print the shapes of one example's tensorized waveform and the corresponding spectrogram

# %%
for waveform, label in waveform_ds.take(1):
    label = label.numpy()
    spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
# Out:
# Label: b'1'
# Waveform shape: (5000,)
# Spectrogram shape: (38, 129, 1)

# %% [markdown]
# Defining a function for displaying a spectrogram:

# %%
def plot_spectrogram(spectrogram, ax):
    if len(spectrogram.shape) > 2:
        assert len(spectrogram.shape) == 3
        spectrogram = np.squeeze(spectrogram, axis=-1)
        # Convert the frequencies to log scale and transpose, so that the time is
        # represented on the x-axis (columns).
        # Add an epsilon to avoid taking a log of zero.
        log_spec = np.log(spectrogram.T + np.finfo(float).eps)
        height = log_spec.shape[0]
        width = log_spec.shape[1]
        X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
        Y = range(height)
        ax.pcolormesh(X, Y, log_spec, shading='auto')

# %% [markdown]
# Plot the example's waveform over time and the corresponding spectrogram (frequencies over time):

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, data_length])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %% [markdown]
# Now, define a function that transforms the waveform dataset into spectrograms and their corresponding labels as integer IDs:

# %%
def get_spectrogram_and_label_id(ecg, label):
    spectrogram = get_spectrogram(ecg)
    label_id = tf.math.argmax(label == commands)
    return spectrogram, label_id

# %% [markdown]
# Map `get_spectrogram_and_label_id` across the dataset's elements with `Dataset.map`:

# %%
spectrogram_ds = waveform_ds.map(
  map_func=get_spectrogram_and_label_id,
  num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Examine the spectrograms for different examples of the dataset:

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))

for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(spectrogram.numpy(), ax)
    ax.set_title(commands[label_id.numpy()])
    ax.axis('off')

plt.show()

# %% [markdown]
# ## Build and train the model
#
# Repeat the training set preprocessing on the validation and test sets:

# %%
def preprocess_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    output_ds = files_ds.map(
      map_func=get_waveform_and_label,
      num_parallel_calls=AUTOTUNE)
    output_ds = output_ds.map(
      map_func=get_spectrogram_and_label_id,
      num_parallel_calls=AUTOTUNE)
    return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %% [markdown]
# Batch the training and validation sets for model training:

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Add `Dataset.cache` and `Dataset.prefetch` operations to reduce read latency while training the model:

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %% [markdown]
# `tf.keras.Sequential` model uses the following Keras preprocessing layers:
#
# - `tf.keras.layers.Normalization`: to normalize each pixel in the image based on its mean and standard deviation.
#
# For the `Normalization` layer, its `adapt` method would first need to be called on the training data in order to compute aggregate statistics (that is, the mean and the standard deviation).

# %% [markdown]
# # CNN/Bi-LSTM model
#
# The CNN part of the algorithm consists of three blocks that downsample the data through convolutions. Each block consists of a CNN layer, a max pooling layer, and a dropout layer.

# %%
for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
print('Input shape:', input_shape)
num_labels = len(commands)

# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
norm_layer.adapt(data=spectrogram_ds.map(map_func=lambda spec, label: spec))


model = models.Sequential([
    layers.Input(shape=(input_shape[0],input_shape[1])),
    norm_layer,
    layers.Conv1D(32, 3, activation='relu'),
    layers.MaxPooling1D(),
    layers.Dropout(0.2),
    layers.Conv1D(32, 3, activation='relu'),
    layers.MaxPooling1D(),
    layers.Dropout(0.2),
    layers.Conv1D(64, 3, activation='relu'),
    layers.MaxPooling1D(),
    layers.Dropout(0.2),
    layers.Dense(100), 
    layers.LSTM(100),
    layers.Dropout(0.2),
    layers.Dense(29),
    layers.Dense(num_labels, activation='sigmoid'),
])

model.summary()
# Out:
# Input shape: (38, 129, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 38, 129)          3
#  n)
#
#  conv1d (Conv1D)             (None, 36, 32)            12416
#
#  max_pooling1d (MaxPooling1D  (None, 18, 32)           0
#  )
#
#  dropout (Dropout)           (None, 18, 32)            0
#
#  conv1d_1 (Conv1D)           (None, 16, 32)            3104
#
#  max_pooling1d_1 (MaxPooling  (None, 8, 32)            0
#  1D)
#
#  dropout_1 (Dropout)         (None, 8, 32)             0
#
#  conv1d_2 (Conv1D)           (None, 6, 64)             6208
#
#  max_pooling1d_2 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  dropout_2 (Dropout)         (None, 3, 64)             0
#
#  dense (Dense)               (None, 3, 100)            6500
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 29)                2929
#
#  dense_2 (Dense)             (None, 2)                 60
#
# =================================================================
# Total params: 111,620
# Trainable params: 111,617
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Configure the Keras model with the Adam optimizer and the cross-entropy loss:

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# Train the model over 300 epochs:

# %%
EPOCHS = 300
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
#     callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=30),
)
# Out:
# Epoch 1/300
# C:\Users\kirin\anaconda3\envs\tensorFlowKeras\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 174/174 [==============================] - 11s 47ms/step - loss: 0.3210 - accuracy: 0.8899 - val_loss: 0.2571 - val_accuracy: 0.9274
# Epoch 2/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.2256 - accuracy: 0.9269 - val_loss: 0.1940 - val_accuracy: 0.9346
# Epoch 3/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.1792 - accuracy: 0.9382 - val_loss: 0.1864 - val_accuracy: 0.9360
# Epoch 4/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.1572 - accuracy: 0.9437 - val_loss: 0.1691 - val_accuracy: 0.9382
# Epoch 5/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1490 - accuracy: 0.9454 - val_loss: 0.1466 - val_accuracy: 0.9461
# Epoch 6/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1405 - accuracy: 0.9474 - val_loss: 0.1394 - val_accuracy: 0.9490
# Epoch 7/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1339 - accuracy: 0.9494 - val_loss: 0.1330 - val_accuracy: 0.9497
# Epoch 8/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.1323 - accuracy: 0.9501 - val_loss: 0.1295 - val_accuracy: 0.9526
# Epoch 9/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1243 - accuracy: 0.9519 - val_loss: 0.1331 - val_accuracy: 0.9518
# Epoch 10/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1199 - accuracy: 0.9545 - val_loss: 0.1306 - val_accuracy: 0.9504
# Epoch 11/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1193 - accuracy: 0.9551 - val_loss: 0.1185 - val_accuracy: 0.9561
# Epoch 12/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1164 - accuracy: 0.9553 - val_loss: 0.1235 - val_accuracy: 0.9547
# Epoch 13/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1156 - accuracy: 0.9544 - val_loss: 0.1162 - val_accuracy: 0.9569
# Epoch 14/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1123 - accuracy: 0.9561 - val_loss: 0.1216 - val_accuracy: 0.9547
# Epoch 15/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.1101 - accuracy: 0.9570 - val_loss: 0.1141 - val_accuracy: 0.9569
# Epoch 16/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.1099 - accuracy: 0.9567 - val_loss: 0.1135 - val_accuracy: 0.9569
# Epoch 17/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.1096 - accuracy: 0.9570 - val_loss: 0.1121 - val_accuracy: 0.9561
# Epoch 18/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1095 - accuracy: 0.9580 - val_loss: 0.1112 - val_accuracy: 0.9576
# Epoch 19/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.1050 - accuracy: 0.9595 - val_loss: 0.1104 - val_accuracy: 0.9569
# Epoch 20/300
# 174/174 [==============================] - 4s 20ms/step - loss: 0.1040 - accuracy: 0.9599 - val_loss: 0.1130 - val_accuracy: 0.9554
# Epoch 21/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.1044 - accuracy: 0.9604 - val_loss: 0.1049 - val_accuracy: 0.9583
# Epoch 22/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1017 - accuracy: 0.9605 - val_loss: 0.1065 - val_accuracy: 0.9569
# Epoch 23/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1021 - accuracy: 0.9604 - val_loss: 0.1060 - val_accuracy: 0.9576
# Epoch 24/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1011 - accuracy: 0.9603 - val_loss: 0.1065 - val_accuracy: 0.9576
# Epoch 25/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1011 - accuracy: 0.9606 - val_loss: 0.1058 - val_accuracy: 0.9569
# Epoch 26/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.1009 - accuracy: 0.9619 - val_loss: 0.1059 - val_accuracy: 0.9583
# Epoch 27/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0994 - accuracy: 0.9624 - val_loss: 0.1064 - val_accuracy: 0.9605
# Epoch 28/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0982 - accuracy: 0.9618 - val_loss: 0.1028 - val_accuracy: 0.9633
# Epoch 29/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0970 - accuracy: 0.9636 - val_loss: 0.1010 - val_accuracy: 0.9633
# Epoch 30/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0967 - accuracy: 0.9646 - val_loss: 0.1012 - val_accuracy: 0.9626
# Epoch 31/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0961 - accuracy: 0.9638 - val_loss: 0.1002 - val_accuracy: 0.9633
# Epoch 32/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0966 - accuracy: 0.9622 - val_loss: 0.0999 - val_accuracy: 0.9641
# Epoch 33/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0942 - accuracy: 0.9641 - val_loss: 0.0983 - val_accuracy: 0.9641
# Epoch 34/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0952 - accuracy: 0.9642 - val_loss: 0.1030 - val_accuracy: 0.9626
# Epoch 35/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0946 - accuracy: 0.9641 - val_loss: 0.0980 - val_accuracy: 0.9641
# Epoch 36/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0922 - accuracy: 0.9651 - val_loss: 0.0999 - val_accuracy: 0.9641
# Epoch 37/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0934 - accuracy: 0.9641 - val_loss: 0.1006 - val_accuracy: 0.9641
# Epoch 38/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0929 - accuracy: 0.9644 - val_loss: 0.0983 - val_accuracy: 0.9619
# Epoch 39/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0921 - accuracy: 0.9659 - val_loss: 0.0974 - val_accuracy: 0.9619
# Epoch 40/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0917 - accuracy: 0.9658 - val_loss: 0.1041 - val_accuracy: 0.9597
# Epoch 41/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0920 - accuracy: 0.9664 - val_loss: 0.0995 - val_accuracy: 0.9626
# Epoch 42/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0900 - accuracy: 0.9649 - val_loss: 0.0988 - val_accuracy: 0.9633
# Epoch 43/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0906 - accuracy: 0.9662 - val_loss: 0.1009 - val_accuracy: 0.9633
# Epoch 44/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0889 - accuracy: 0.9672 - val_loss: 0.0995 - val_accuracy: 0.9633
# Epoch 45/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0880 - accuracy: 0.9667 - val_loss: 0.0997 - val_accuracy: 0.9633
# Epoch 46/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0899 - accuracy: 0.9656 - val_loss: 0.0980 - val_accuracy: 0.9641
# Epoch 47/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0878 - accuracy: 0.9687 - val_loss: 0.0972 - val_accuracy: 0.9641
# Epoch 48/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0867 - accuracy: 0.9673 - val_loss: 0.0984 - val_accuracy: 0.9626
# Epoch 49/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0876 - accuracy: 0.9672 - val_loss: 0.0945 - val_accuracy: 0.9641
# Epoch 50/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0852 - accuracy: 0.9681 - val_loss: 0.1030 - val_accuracy: 0.9626
# Epoch 51/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0868 - accuracy: 0.9678 - val_loss: 0.1018 - val_accuracy: 0.9626
# Epoch 52/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.
300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0517 - accuracy: 0.9813 - val_loss: 0.1039 - val_accuracy: 0.9676
# Epoch 209/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0526 - accuracy: 0.9807 - val_loss: 0.1174 - val_accuracy: 0.9626
# Epoch 210/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0531 - accuracy: 0.9796 - val_loss: 0.1039 - val_accuracy: 0.9655
# Epoch 211/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0522 - accuracy: 0.9806 - val_loss: 0.1057 - val_accuracy: 0.9684
# Epoch 212/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0500 - accuracy: 0.9801 - val_loss: 0.1018 - val_accuracy: 0.9698
# Epoch 213/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0511 - accuracy: 0.9799 - val_loss: 0.1066 - val_accuracy: 0.9691
# Epoch 214/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0502 - accuracy: 0.9809 - val_loss: 0.1106 - val_accuracy: 0.9676
# Epoch 215/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0497 - accuracy: 0.9811 - val_loss: 0.1097 - val_accuracy: 0.9669
# Epoch 216/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0525 - accuracy: 0.9792 - val_loss: 0.1038 - val_accuracy: 0.9676
# Epoch 217/300
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0510 - accuracy: 0.9794 - val_loss: 0.1038 - val_accuracy: 0.9684
# Epoch 218/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0494 - accuracy: 0.9827 - val_loss: 0.1028 - val_accuracy: 0.9676
# Epoch 219/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0515 - accuracy: 0.9798 - val_loss: 0.1043 - val_accuracy: 0.9669
# Epoch 220/300
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0488 - accuracy: 0.9817 - val_loss: 0.1090 - val_accuracy: 0.9669
# Epoch 221/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0512 - accuracy: 0.9811 - val_loss: 0.1055 - val_accuracy: 0.9676
# Epoch 222/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0494 - accuracy: 0.9802 - val_loss: 0.1139 - val_accuracy: 0.9676
# Epoch 223/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0529 - accuracy: 0.9806 - val_loss: 0.1053 - val_accuracy: 0.9676
# Epoch 224/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0524 - accuracy: 0.9796 - val_loss: 0.1076 - val_accuracy: 0.9655
# Epoch 225/300
# 174/174 [==============================] - 3s 20ms/step - loss: 0.0455 - accuracy: 0.9820 - val_loss: 0.1061 - val_accuracy: 0.9684
# Epoch 226/300
# 174/174 [==============================] - 3s 20ms/step - loss: 0.0548 - accuracy: 0.9792 - val_loss: 0.1045 - val_accuracy: 0.9669
# Epoch 227/300
# 174/174 [==============================] - 3s 20ms/step - loss: 0.0537 - accuracy: 0.9792 - val_loss: 0.1020 - val_accuracy: 0.9662
# Epoch 228/300
# 174/174 [==============================] - 3s 20ms/step - loss: 0.0508 - accuracy: 0.9805 - val_loss: 0.1087 - val_accuracy: 0.9662
# Epoch 229/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0475 - accuracy: 0.9813 - val_loss: 0.1037 - val_accuracy: 0.9691
# Epoch 230/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0487 - accuracy: 0.9807 - val_loss: 0.1082 - val_accuracy: 0.9669
# Epoch 231/300
# 174/174 [==============================] - 3s 20ms/step - loss: 0.0443 - accuracy: 0.9828 - val_loss: 0.1114 - val_accuracy: 0.9669
# Epoch 232/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0476 - accuracy: 0.9820 - val_loss: 0.1125 - val_accuracy: 0.9669
# Epoch 233/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0534 - accuracy: 0.9796 - val_loss: 0.1042 - val_accuracy: 0.9669
# Epoch 234/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0486 - accuracy: 0.9828 - val_loss: 0.1029 - val_accuracy: 0.9684
# Epoch 235/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0478 - accuracy: 0.9826 - val_loss: 0.1009 - val_accuracy: 0.9676
# Epoch 236/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0469 - accuracy: 0.9814 - val_loss: 0.1075 - val_accuracy: 0.9662
# Epoch 237/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0460 - accuracy: 0.9826 - val_loss: 0.1055 - val_accuracy: 0.9669
# Epoch 238/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0489 - accuracy: 0.9806 - val_loss: 0.1070 - val_accuracy: 0.9676
# Epoch 239/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0478 - accuracy: 0.9821 - val_loss: 0.1096 - val_accuracy: 0.9662
# Epoch 240/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0478 - accuracy: 0.9810 - val_loss: 0.0998 - val_accuracy: 0.9691
# Epoch 241/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0457 - accuracy: 0.9824 - val_loss: 0.1045 - val_accuracy: 0.9698
# Epoch 242/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0461 - accuracy: 0.9831 - val_loss: 0.1047 - val_accuracy: 0.9698
# Epoch 243/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0486 - accuracy: 0.9818 - val_loss: 0.1033 - val_accuracy: 0.9691
# Epoch 244/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0462 - accuracy: 0.9816 - val_loss: 0.1100 - val_accuracy: 0.9676
# Epoch 245/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0512 - accuracy: 0.9800 - val_loss: 0.0993 - val_accuracy: 0.9691
# Epoch 246/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0452 - accuracy: 0.9835 - val_loss: 0.1057 - val_accuracy: 0.9684
# Epoch 247/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0482 - accuracy: 0.9818 - val_loss: 0.1090 - val_accuracy: 0.9676
# Epoch 248/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0471 - accuracy: 0.9819 - val_loss: 0.1017 - val_accuracy: 0.9684
# Epoch 249/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0430 - accuracy: 0.9830 - val_loss: 0.1125 - val_accuracy: 0.9684
# Epoch 250/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0451 - accuracy: 0.9826 - val_loss: 0.1052 - val_accuracy: 0.9684
# Epoch 251/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0456 - accuracy: 0.9827 - val_loss: 0.1125 - val_accuracy: 0.9676
# Epoch 252/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0465 - accuracy: 0.9825 - val_loss: 0.1071 - val_accuracy: 0.9698
# Epoch 253/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0457 - accuracy: 0.9827 - val_loss: 0.1080 - val_accuracy: 0.9676
# Epoch 254/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0447 - accuracy: 0.9824 - val_loss: 0.1074 - val_accuracy: 0.9684
# Epoch 255/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0464 - accuracy: 0.9825 - val_loss: 0.1073 - val_accuracy: 0.9684
# Epoch 256/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0439 - accuracy: 0.9838 - val_loss: 0.1087 - val_accuracy: 0.9676
# Epoch 257/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0461 - accuracy: 0.9827 - val_loss: 0.1037 - val_accuracy: 0.9684
# Epoch 258/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0465 - accuracy: 0.9820 - val_loss: 0.1185 - val_accuracy: 0.9676
# Epoch 259/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0418 - accuracy: 0.9836 - val_loss: 0.1091 - val_accuracy: 0.9691
# Epoch 260/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0458 - accuracy: 0.9812 - val_loss: 0.1020 - val_accuracy: 0.9676
# Epoch 261/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0423 - accuracy: 0.9833 - val_loss: 0.1065 - val_accuracy: 0.9676
# Epoch 262/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0438 - accuracy: 0.9835 - val_loss: 0.1121 - val_accuracy: 0.9669
# Epoch 263/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0418 - accuracy: 0.9835 - val_loss: 0.1097 - val_accuracy: 0.9662
# Epoch 264/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0431 - accuracy: 0.9845 - val_loss: 0.1082 - val_accuracy: 0.9684
# Epoch 265/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0447 - accuracy: 0.9829 - val_loss: 0.1125 - val_accuracy: 0.9669
# Epoch 266/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0443 - accuracy: 0.9831 - val_loss: 0.1124 - val_accuracy: 0.9684
# Epoch 267/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0424 - accuracy: 0.9836 - val_loss: 0.1111 - val_accuracy: 0.9691
# Epoch 268/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0431 - accuracy: 0.9832 - val_loss: 0.1162 - val_accuracy: 0.9676
# Epoch 269/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0467 - accuracy: 0.9820 - val_loss: 0.1080 - val_accuracy: 0.9676
# Epoch 270/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0437 - accuracy: 0.9836 - val_loss: 0.1178 - val_accuracy: 0.9655
# Epoch 271/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0448 - accuracy: 0.9823 - val_loss: 0.1047 - val_accuracy: 0.9698
# Epoch 272/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0442 - accuracy: 0.9835 - val_loss: 0.1046 - val_accuracy: 0.9691
# Epoch 273/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0412 - accuracy: 0.9843 - val_loss: 0.1133 - val_accuracy: 0.9655
# Epoch 274/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0425 - accuracy: 0.9850 - val_loss: 0.1123 - val_accuracy: 0.9676
# Epoch 275/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0401 - accuracy: 0.9854 - val_loss: 0.1168 - val_accuracy: 0.9669
# Epoch 276/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0399 - accuracy: 0.9845 - val_loss: 0.1107 - val_accuracy: 0.9669
# Epoch 277/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0419 - accuracy: 0.9841 - val_loss: 0.1185 - val_accuracy: 0.9669
# Epoch 278/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0442 - accuracy: 0.9833 - val_loss: 0.1101 - val_accuracy: 0.9669
# Epoch 279/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0408 - accuracy: 0.9851 - val_loss: 0.1101 - val_accuracy: 0.9698
# Epoch 280/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0422 - accuracy: 0.9830 - val_loss: 0.1193 - val_accuracy: 0.9684
# Epoch 281/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0411 - accuracy: 0.9851 - val_loss: 0.1334 - val_accuracy: 0.9655
# Epoch 282/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0426 - accuracy: 0.9845 - val_loss: 0.1192 - val_accuracy: 0.9662
# Epoch 283/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0451 - accuracy: 0.9827 - val_loss: 0.1110 - val_accuracy: 0.9676
# Epoch 284/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0443 - accuracy: 0.9823 - val_loss: 0.1045 - val_accuracy: 0.9676
# Epoch 285/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0414 - accuracy: 0.9831 - val_loss: 0.1138 - val_accuracy: 0.9676
# Epoch 286/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0416 - accuracy: 0.9832 - val_loss: 0.1100 - val_accuracy: 0.9698
# Epoch 287/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0438 - accuracy: 0.9842 - val_loss: 0.1227 - val_accuracy: 0.9662
# Epoch 288/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0384 - accuracy: 0.9835 - val_loss: 0.1247 - val_accuracy: 0.9662
# Epoch 289/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0423 - accuracy: 0.9837 - val_loss: 0.1127 - val_accuracy: 0.9676
# Epoch 290/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0407 - accuracy: 0.9849 - val_loss: 0.1225 - val_accuracy: 0.9669
# Epoch 291/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0410 - accuracy: 0.9839 - val_loss: 0.1074 - val_accuracy: 0.9705
# Epoch 292/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0423 - accuracy: 0.9835 - val_loss: 0.1133 - val_accuracy: 0.9684
# Epoch 293/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0383 - accuracy: 0.9860 - val_loss: 0.1152 - val_accuracy: 0.9698
# Epoch 294/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0407 - accuracy: 0.9843 - val_loss: 0.1096 - val_accuracy: 0.9684
# Epoch 295/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0385 - accuracy: 0.9845 - val_loss: 0.1260 - val_accuracy: 0.9669
# Epoch 296/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0371 - accuracy: 0.9853 - val_loss: 0.1257 - val_accuracy: 0.9684
# Epoch 297/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0411 - accuracy: 0.9839 - val_loss: 0.1154 - val_accuracy: 0.9676
# Epoch 298/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0398 - accuracy: 0.9851 - val_loss: 0.1140 - val_accuracy: 0.9698
# Epoch 299/300
# 174/174 [==============================] - 3s 18ms/step - loss: 0.0379 - accuracy: 0.9856 - val_loss: 0.1167 - val_accuracy: 0.9684
# Epoch 300/300
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0393 - accuracy: 0.9857 - val_loss: 0.1131 - val_accuracy: 0.9684

# %% [markdown]
# Let's plot the training and validation loss curves to check how the model has improved during training:

# %%
metrics = history.history
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

# %% [markdown]
# Save the model for later usage:

# %%
# model.save(model_save_path+'/'+parameters['model_name'])

# %% [markdown]
# Load previously trained model:

# %%
# model = tf.keras.models.load_model(model_save_path+'/'+parameters['model_name'])

# %% [markdown]
# ## Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
test_ecg = []
test_labels = []

for ecg, label in test_ds:
    test_ecg.append(ecg.numpy())
    test_labels.append(label.numpy())

test_ecg = np.array(test_ecg)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_ecg), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc}')
# Out:
# 44/44 [==============================] - 1s 4ms/step
# Test set accuracy: 0.9726815240833933

# %% [markdown]
# <!-- ![image.png](attachment:image.png) -->
#
#
# Sensitivity=[a/(a+c)]×100
#
# Specificity=[d/(b+d)]×100

# %%
true_positive_linus = 0
for i in range(len(y_true)):
    true_positive_linus += (y_true[i] * y_pred[i])
    
false_negative_linus = sum(y_true) - true_positive_linus

sensitivity_linus = (true_positive_linus / (true_positive_linus + false_negative_linus)) * 100

print('Sensitivity', sensitivity_linus)

false_positive_linus = sum(y_pred) - true_positive_linus
true_negative_linus = len(y_pred) - true_positive_linus - false_positive_linus - false_negative_linus

specificity_linus = (true_negative_linus / (false_positive_linus + true_negative_linus)) * 100

print('Specificity', specificity_linus)
# Out:
# Sensitivity 99.74468085106383
# Specificity 83.79629629629629

# %% [markdown]
# F1 score

# %% [markdown]
# <!-- ![image.png](attachment:image.png) -->

# %%
f1_score_linus = ((true_positive_linus)/(true_positive_linus + 0.5 * (false_positive_linus + false_negative_linus)))

print('F1 score', f1_score_linus)
# Out:
# F1 score 0.984047019311503

# %% [markdown]
# ### Display a confusion matrix
#
# Use a <a href="https://developers.google.com/machine-learning/glossary#confusion-matrix" class="external">confusion matrix</a> to check how well the model did classifying each of the commands in the test set:

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# # External validation BUTQDB

# %% [markdown]
# Import data and make sure that the labels are balanced, the 0-label group is the smallest. So, load that first and then load the 1-label group with the same size.

# %%
test_dir = parameters['path_BUTQDB_test']
test_dir = pathlib.Path(test_dir)
test_filenames0 = tf.io.gfile.glob(str(test_dir) + '/0/*')
test_filenames0 = tf.random.shuffle(test_filenames0)
test_filenames1 = tf.io.gfile.glob(str(test_dir) + '/1/*')
test_filenames1 = tf.random.shuffle(test_filenames1)
test_filenames1 = test_filenames1[:len(test_filenames0)] 
test_filenames = tf.concat([test_filenames0, test_filenames1], 0)
test_num_samples = len(test_filenames)
print('Number of total samples:', test_num_samples)
print('Number of samples per label:', len(tf.io.gfile.listdir(str(test_dir/commands[0]))))
# print('Example file tensor:', test_filenames[0])
# Out:
# Number of total samples: 10570
# Number of samples per label: 5285

# %% [markdown]
# Preprocess the data:

# %%
def preprocess_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    output_ds = files_ds.map(
      map_func=get_waveform_and_label,
      num_parallel_calls=AUTOTUNE)
    output_ds = output_ds.map(
      map_func=get_spectrogram_and_label_id,
      num_parallel_calls=AUTOTUNE)
    return output_ds

# %% [markdown]
# Display the spectrograms of the created dataset:

# %%
test_but_qdb = preprocess_dataset(test_filenames)

rows = 5
cols = 5
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))

for i, (spectrogram, label_id) in enumerate(test_but_qdb.take(n)):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(spectrogram.numpy(), ax)
    ax.set_title(commands[label_id.numpy()])
    ax.axis('off')

plt.show()
# batch_size_ptb = 2
# test_ptb_ds = test_ptb_ds.batch(batch_size_ptb)
test_but_qdb = test_but_qdb.cache().prefetch(AUTOTUNE)

# %%
def preprocess_dataset_plot(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    output_ds = files_ds.map(
      map_func=get_waveform_and_label,
      num_parallel_calls=AUTOTUNE)
    return output_ds

# %%
# val_but_qdb_plot = preprocess_dataset_plot(val_filenames)
    
# # val = val_but_qdb_plot.take(10)
# # for i in range(10):
# n = 2

# for waveform_but_qdb, label_but_qdb in val_but_qdb_plot.take(n):    
#     label_but_qdb = label_but_qdb.numpy()
#     spectrogram_but_qdb = get_spectrogram(waveform_but_qdb)

#     print('Label:', label_but_qdb)
#     print('Waveform shape:', waveform_but_qdb.shape)
#     print('Spectrogram shape:', spectrogram_but_qdb.shape)

#     fig, axes = plt.subplots(2, figsize=(12, 8))
#     timescale = np.arange(waveform_but_qdb.shape[0])
#     axes[0].plot(timescale, waveform_but_qdb.numpy())
#     axes[0].set_title('Waveform')
#     axes[0].set_xlim([0, data_length])

#     plot_spectrogram(spectrogram_but_qdb.numpy(), axes[1])
#     axes[1].set_title('Spectrogram')
#     plt.show()

# %% [markdown]
# ## Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
test_but_qdb_ecg = []
test_but_qdb_labels = []

for ecg, label in test_but_qdb:
    test_but_qdb_ecg.append(ecg.numpy())
    test_but_qdb_labels.append(label.numpy())

test_but_qdb_ecg = np.array(test_but_qdb_ecg)
test_but_qdb_labels = np.array(test_but_qdb_labels)

# %%
y_pred_but_qdb = np.argmax(model.predict(test_but_qdb_ecg), axis=1)
y_true_but_qdb = test_but_qdb_labels

test_acc_but_qdb = sum(y_pred_but_qdb == y_true_but_qdb) / len(y_true_but_qdb)
print(f'Test set accuracy: {test_acc_but_qdb}')
# Out:
# 331/331 [==============================] - 17s 50ms/step
# Test set accuracy: 0.9806054872280038

# %%
true_positive_but_qdb = 0
for i in range(len(y_true_but_qdb)):
    true_positive_but_qdb += (y_true_but_qdb[i] * y_pred_but_qdb[i])
    
false_negative_but_qdb = sum(y_true_but_qdb) - true_positive_but_qdb

sensitivity_but_qdb = (true_positive_but_qdb / (true_positive_but_qdb + false_negative_but_qdb)) * 100

print('Sensitivity', sensitivity_but_qdb)

false_positive_but_qdb = sum(y_pred_but_qdb) - true_positive_but_qdb
true_negative_but_qdb = len(y_pred_but_qdb) - true_positive_but_qdb - false_positive_but_qdb - false_negative_but_qdb

specificity_but_qdb = (true_negative_but_qdb / (false_positive_but_qdb + true_negative_but_qdb)) * 100

print('Specificity', specificity_but_qdb)
# Out:
# Sensitivity 99.41343424787134
# Specificity 96.70766319772942

# %%
f1_score_but_qdb = ((true_positive_but_qdb)/(true_positive_but_qdb + 0.5 * (false_positive_but_qdb + false_negative_but_qdb)))

print('F1 score', f1_score_but_qdb)
# Out:
# F1 score 0.9808643703911136

# %% [markdown]
# ### Display a confusion matrix
#
# Use a <a href="https://developers.google.com/machine-learning/glossary#confusion-matrix" class="external">confusion matrix</a> to check how well the model did classifying each of the commands in the test set:

# %%
confusion_mtx = tf.math.confusion_matrix(y_true_but_qdb, y_pred_but_qdb)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
